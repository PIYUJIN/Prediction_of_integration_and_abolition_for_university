# %% [markdown]
# <a href="https://colab.research.google.com/github/jeewonkimm2/Business_Analytics/blob/main/Final/future_features_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import csv
# from pandas import DataFrame

# %%
previous = pd.read_excel('2025.xlsx', engine='openpyxl')
future = pd.read_excel('future_2026.xlsx', engine='openpyxl')
sub_2021 = pd.read_excel('2021_sub_1.xlsx', engine='openpyxl')
sub_2020 = pd.read_excel('2020_sub_1.xlsx', engine='openpyxl')
sub_2019 = pd.read_excel('2019_sub_1.xlsx', engine='openpyxl')

# %%
previous
# Out:
#         연도  시도    대계열    중계열  모집인원_학부_계  지원자_전체_계  입학자_전체_계  Gov_Spnsorship  \
# 0     2025  강원   인문계열  언어ㆍ문학         33       NaN        35               1
# 1     2025  강원   인문계열  언어ㆍ문학         26       NaN        26               1
# 2     2025  강원   인문계열  언어ㆍ문학         33       NaN        34               1
# 3     2025  강원   인문계열  언어ㆍ문학         19       NaN        18               1
# 4     2025  강원   인문계열   인문과학         22       NaN        21               1
# ...    ...  ..    ...    ...        ...       ...       ...             ...
# 3712  2025  대구   자연계열   생활과학        220       NaN       199               0
# 3713  2025  충남   인문계열   인문과학         16       NaN        16               0
# 3714  2025  충남   공학계열     건축         21       NaN        21               0
# 3715  2025  충남   공학계열     건축         16       NaN        16               0
# 3716  2025  충남  예체능계열   응용예술         41       NaN        41               0
#
# ...

# %%
# schoolage_2022 = 957	 
# schoolage_2023 = 922	 
# schoolage_2024 = 883	 
# schoolage_2025 = 895	 
schoolage_2026 = 943

# %% [markdown]
# **change future features about 2022**

# %%
future['schoolage'] = schoolage_2026

# %%
future
# Out:
#         연도  시도    대계열    중계열  모집인원_학부_계  지원자_전체_계  입학자_전체_계  Gov_Spnsorship  \
# 0     2026  강원   인문계열  언어ㆍ문학         33       NaN        35               1
# 1     2026  강원   인문계열  언어ㆍ문학         26       NaN        26               1
# 2     2026  강원   인문계열  언어ㆍ문학         33       NaN        34               1
# 3     2026  강원   인문계열  언어ㆍ문학         19       NaN        18               1
# 4     2026  강원   인문계열   인문과학         22       NaN        21               1
# ...    ...  ..    ...    ...        ...       ...       ...             ...
# 3712  2026  대구   자연계열   생활과학        220       NaN       199               0
# 3713  2026  충남   인문계열   인문과학         16       NaN        16               0
# 3714  2026  충남   공학계열     건축         21       NaN        21               0
# 3715  2026  충남   공학계열     건축         16       NaN        16               0
# 3716  2026  충남  예체능계열   응용예술         41       NaN        41               0
#
# ...

# %%
im = list(previous['immigration'].values)
print(im)
# Out:
# [-356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -356, -734, -734, -734, -734, -734, -734, -734, -734, -734, -734, -734, -734, -734, -734, -734, -734, -734, -734, -734, -734, -734, -734, -734, -734, -734, -734, -734, -734, -734, -734, -734, -734, -734, -734, -734, -734, -734, -734, -734, -734, -734, -734, -734, -734, -734, -734, -734, -734, -734, -734, -734, -734, -734, -734, -734, -734, -734, -734, -734, -734, -734, -734, -734, -734, -734, -734, -734, -734, -734, -734, -734, -
# ...

# %%
nm = list(previous['Net_Mover'].values)
print(nm)
# Out:
# [16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 16721.0, 13888.0, 13888.0, 13888.0, 13888.0, 13888.0, 13888.0, 13888.0, 13888.0, 13888.0, 13888.0, 13888.0, 13888.0, 13888.0, 13888.0, 13888.0, 13888.0
# ...

# %%
ft = list(previous['Total_fertility_rate'].values)
print(ft)
# Out:
# [0.7729999999999997, 0.7729999999999997, 0.7729999999999997, 0.7729999999999997, 0.7729999999999997, 0.7729999999999997, 0.7729999999999997, 0.7729999999999997, 0.7729999999999997, 0.7729999999999997, 0.7729999999999997, 0.7729999999999997, 0.7729999999999997, 0.7729999999999997, 0.7729999999999997, 0.7729999999999997, 0.7729999999999997, 0.7729999999999997, 0.7729999999999997, 0.7729999999999997, 0.7729999999999997, 0.7729999999999997, 0.7729999999999997, 0.7729999999999997, 0.7729999999999997, 0.7729999999999997, 0.7729999999999997, 0.7729999999999997, 0.7729999999999997, 0.7729999999999997, 0.7729999999999997, 0.7729999999999997, 0.7729999999999997, 0.7729999999999997, 0.7729999999999997, 0.7729999999999997, 0.7729999999999997, 0.7729999999999997, 0.7729999999999997, 0.7729999999999997, 0.7729999999999997, 0.7729999999999997, 0.7729999999999997, 0.7729999999999997, 0.7729999999999997, 0.7729999999999997, 0.7729999999999997, 0.7729999999999997, 0.7729999999999997, 0.772999999999999
# ...

# %%
avg_net = []
for i in range(len(sub_2019)) :
    net_mover_2019 = sub_2019.loc[i]
    net_mover_2020 = sub_2020.loc[i]
    net_mover_2021 = sub_2021.loc[i]
    net_mover_dif = (float(net_mover_2019['Net_Mover']) - float(net_mover_2020['Net_Mover'])) + (float(net_mover_2020['Net_Mover']) - float(net_mover_2021['Net_Mover']))
    avg_net.append(net_mover_dif / 2)
print(avg_net)
# Out:
# [28327.5, -2225.5, 323.0, -6880.0, 1004.0, -3705.5, 1751.0, 4819.5, -7925.5, -2510.0, -448.5, -4658.0, -3473.5, -2150.5, -3954.0, 2196.5, -490.5]

# %%
avg_imm = []
for i in range(len(sub_2019)) :
    immigration_2019 = sub_2019.loc[i]
    immigration_2020 = sub_2020.loc[i]
    immigration_2021 = sub_2021.loc[i]
    # print(immigration_2019)
    # print(immigration_2020)
    immigration_dif = (float(immigration_2019['immigration']) - float(immigration_2020['immigration'])) + (float(immigration_2020['immigration']) - float(immigration_2021['immigration']))
    avg_imm.append(immigration_dif / 2)
print(avg_imm)
# Out:
# [4585.0, 867.0, 571.0, 950.0, 409.0, 359.0, 189.0, 89.0, 5417.0, 193.0, 83.0, 412.0, 199.0, 415.0, 121.0, 358.0, 130.0]

# %%
avg_ft = []
for i in range(len(sub_2019)) :
    fertility_rate_2019 = sub_2019.loc[i]
    fertility_rate_2020 = sub_2020.loc[i]
    fertility_rate_2021 = sub_2021.loc[i]
    fertility_rate_dif = (float(fertility_rate_2019['Total_fertility_rate']) - float(fertility_rate_2020['Total_fertility_rate'])) + (float(fertility_rate_2020['Total_fertility_rate']) - float(fertility_rate_2021['Total_fertility_rate']))
    avg_ft.append(fertility_rate_dif / 2)
print(avg_ft)
# Out:
# [0.045499999999999985, 0.04949999999999999, 0.07350000000000001, 0.08099999999999996, 0.008500000000000008, 0.03649999999999998, 0.07200000000000006, 0.09750000000000003, 0.044999999999999984, 0.051500000000000046, 0.050500000000000045, 0.07450000000000007, 0.0605, 0.10850000000000004, 0.0615, 0.07150000000000001, 0.09700000000000003]

# %%
for i in range(len(future)) :
    # for j in range(len(sub_2022)) :
        target = future.loc[i]
        # target = sub_2022.loc[j]
        if(target['시도']=='서울') :
            future.iat[i,12] = float(im[0]) - float(avg_imm[0])
            future.iat[i,11] = float(nm[0]) - float(avg_net[0])
            future.iat[i,10] = float(ft[0]) - float(avg_ft[0])
        elif(target['시도']=='부산') :
            future.iat[i,12] = float(im[1]) - float(avg_imm[1])
            future.iat[i,11] = float(nm[1]) - float(avg_net[1])
            future.iat[i,10] = float(ft[1]) - float(avg_ft[1])
        elif(target['시도']=='대구') :
            future.iat[i,12] = float(im[2]) - float(avg_imm[2])
            future.iat[i,11] = float(nm[2]) - float(avg_net[2])
            future.iat[i,10] = float(ft[2]) - float(avg_ft[2])
        elif(target['시도']=='인천') :
            future.iat[i,12] = float(im[3]) - float(avg_imm[3])
            future.iat[i,11] = float(nm[3]) - float(avg_net[3])
            future.iat[i,10] = float(ft[3]) - float(avg_ft[3])
        elif(target['시도']=='광주') :
            future.iat[i,12] = float(im[4]) - float(avg_imm[4])
            future.iat[i,11] = float(nm[4]) - float(avg_net[4])
            future.iat[i,10] = float(ft[4]) - float(avg_ft[4])
        elif(target['시도']=='대전') :
            future.iat[i,12] = float(im[5]) - float(avg_imm[5])
            future.iat[i,11] = float(nm[5]) - float(avg_net[5])
            future.iat[i,10] = float(ft[5]) - float(avg_ft[5])
        elif(target['시도']=='울산') :
            future.iat[i,12] = float(im[6]) - float(avg_imm[6])
            future.iat[i,11] = float(nm[6]) - float(avg_net[6])
            future.iat[i,10] = float(ft[6]) - float(avg_ft[6])
        elif(target['시도']=='세종') :
            future.iat[i,12] = float(im[7]) - float(avg_imm[7])
            future.iat[i,11] = float(nm[7]) - float(avg_net[7])
            future.iat[i,10] = float(ft[7]) - float(avg_ft[7])
        elif(target['시도']=='경기') :
            future.iat[i,12] = float(im[8]) - float(avg_imm[8])
            future.iat[i,11] = float(nm[8]) - float(avg_net[8])
            future.iat[i,10] = float(ft[8]) - float(avg_ft[8])
        elif(target['시도']=='강원') :
            future.iat[i,12] = float(im[9]) - float(avg_imm[9])
            future.iat[i,11] = float(nm[9]) - float(avg_net[9])
            future.iat[i,10] = float(ft[9]) - float(avg_ft[9])
        elif(target['시도']=='충북') :
            future.iat[i,12] = float(im[10]) - float(avg_imm[10])
            future.iat[i,11] = float(nm[10]) - float(avg_net[10])
            future.iat[i,10] = float(ft[10]) - float(avg_ft[10])
        elif(target['시도']=='충남') :
            future.iat[i,12] = float(im[11]) - float(avg_imm[11])
            future.iat[i,11] = float(nm[11]) - float(avg_net[11])
            future.iat[i,10] = float(ft[11]) - float(avg_ft[11])
        elif(target['시도']=='전북') :
            future.iat[i,12] = float(im[12]) - float(avg_imm[12])
            future.iat[i,11] = float(nm[12]) - float(avg_net[12])
            future.iat[i,10] = float(ft[12]) - float(avg_ft[12])
        elif(target['시도']=='전남') :
            future.iat[i,12] = float(im[13]) - float(avg_imm[13])
            future.iat[i,11] = float(nm[13]) - float(avg_net[13])
            future.iat[i,10] = float(ft[13]) - float(avg_ft[13])
        elif(target['시도']=='경북') :
            future.iat[i,12] = float(im[14]) - float(avg_imm[14])
            future.iat[i,11] = float(nm[14]) - float(avg_net[14])
            future.iat[i,10] = float(ft[14]) - float(avg_ft[14])
        elif(target['시도']=='경남') :
            future.iat[i,12] = float(im[15]) - float(avg_imm[15])
            future.iat[i,11] = float(nm[15]) - float(avg_net[15])
            future.iat[i,10] = float(ft[15]) - float(avg_ft[15])
        elif(target['시도']=='제주') :
            future.iat[i,12] = float(im[16]) - float(avg_imm[16])
            future.iat[i,11] = float(nm[16]) - float(avg_net[16])
            future.iat[i,10] = float(ft[16]) - float(avg_ft[16])
# future_2022['Total_fertility_rate']

# %%
future
# Out:
#         연도  시도    대계열    중계열  모집인원_학부_계  지원자_전체_계  입학자_전체_계  Gov_Spnsorship  \
# 0     2026  강원   인문계열  언어ㆍ문학         33       NaN        35               1
# 1     2026  강원   인문계열  언어ㆍ문학         26       NaN        26               1
# 2     2026  강원   인문계열  언어ㆍ문학         33       NaN        34               1
# 3     2026  강원   인문계열  언어ㆍ문학         19       NaN        18               1
# 4     2026  강원   인문계열   인문과학         22       NaN        21               1
# ...    ...  ..    ...    ...        ...       ...       ...             ...
# 3712  2026  대구   자연계열   생활과학        220       NaN       199               0
# 3713  2026  충남   인문계열   인문과학         16       NaN        16               0
# 3714  2026  충남   공학계열     건축         21       NaN        21               0
# 3715  2026  충남   공학계열     건축         16       NaN        16               0
# 3716  2026  충남  예체능계열   응용예술         41       NaN        41               0
#
# ...

# %%
future.to_excel('2026.xlsx',index=False)

# %%
future_2022 = pd.read_excel('2022.xlsx', engine='openpyxl')
future_2023 = pd.read_excel('2023.xlsx', engine='openpyxl')
future_2024 = pd.read_excel('2024.xlsx', engine='openpyxl')
future_2025 = pd.read_excel('2025.xlsx', engine='openpyxl')
future_2026 = pd.read_excel('2026.xlsx', engine='openpyxl')

# %%
future_merge = pd.concat([future_2022, future_2023, future_2024, future_2025, future_2026])

future_merge
# Out:
#         연도  시도    대계열    중계열  모집인원_학부_계  지원자_전체_계  입학자_전체_계  Gov_Spnsorship  \
# 0     2022  강원   인문계열  언어ㆍ문학         33       NaN        35               1
# 1     2022  강원   인문계열  언어ㆍ문학         26       NaN        26               1
# 2     2022  강원   인문계열  언어ㆍ문학         33       NaN        34               1
# 3     2022  강원   인문계열  언어ㆍ문학         19       NaN        18               1
# 4     2022  강원   인문계열   인문과학         22       NaN        21               1
# ...    ...  ..    ...    ...        ...       ...       ...             ...
# 3712  2026  대구   자연계열   생활과학        220       NaN       199               0
# 3713  2026  충남   인문계열   인문과학         16       NaN        16               0
# 3714  2026  충남   공학계열     건축         21       NaN        21               0
# 3715  2026  충남   공학계열     건축         16       NaN        16               0
# 3716  2026  충남  예체능계열   응용예술         41       NaN        41               0
#
# ...

# %%
future_merge.to_excel('future.xlsx',index=False)
