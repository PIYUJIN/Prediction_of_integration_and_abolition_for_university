# %% [markdown]
# <a href="https://colab.research.google.com/github/jeewonkimm2/Business_Analytics/blob/main/Final/future_features_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import csv
# from pandas import DataFrame

# %%
future_2022 = pd.read_excel('2022.xlsx', engine='openpyxl')
future_2023 = pd.read_excel('future_2023.xlsx', engine='openpyxl')
sub_2021 = pd.read_excel('2021_sub_1.xlsx', engine='openpyxl')
sub_2020 = pd.read_excel('2020_sub_1.xlsx', engine='openpyxl')
sub_2019 = pd.read_excel('2019_sub_1.xlsx', engine='openpyxl')

# %%
future_2022
# Out:
#         연도  시도    대계열    중계열  모집인원_학부_계  지원자_전체_계  입학자_전체_계  Gov_Spnsorship  \
# 0     2022  강원   인문계열  언어ㆍ문학         33       NaN        35               1
# 1     2022  강원   인문계열  언어ㆍ문학         26       NaN        26               1
# 2     2022  강원   인문계열  언어ㆍ문학         33       NaN        34               1
# 3     2022  강원   인문계열  언어ㆍ문학         19       NaN        18               1
# 4     2022  강원   인문계열   인문과학         22       NaN        21               1
# ...    ...  ..    ...    ...        ...       ...       ...             ...
# 3712  2022  대구   자연계열   생활과학        220       NaN       199               0
# 3713  2022  충남   인문계열   인문과학         16       NaN        16               0
# 3714  2022  충남   공학계열     건축         21       NaN        21               0
# 3715  2022  충남   공학계열     건축         16       NaN        16               0
# 3716  2022  충남  예체능계열   응용예술         41       NaN        41               0
#
# ...

# %%
# schoolage_2022 = 957	 
schoolage_2023 = 922	 
# schoolage_2024 = 883	 
# schoolage_2025 = 895	 
# schoolage_2026 = 943

# %% [markdown]
# **change future features about 2022**

# %%
future_2023['schoolage'] = schoolage_2023

# %%
future_2023
# Out:
#         연도  시도    대계열    중계열  모집인원_학부_계  지원자_전체_계  입학자_전체_계  Gov_Spnsorship  \
# 0     2023  강원   인문계열  언어ㆍ문학         33       NaN        35               1
# 1     2023  강원   인문계열  언어ㆍ문학         26       NaN        26               1
# 2     2023  강원   인문계열  언어ㆍ문학         33       NaN        34               1
# 3     2023  강원   인문계열  언어ㆍ문학         19       NaN        18               1
# 4     2023  강원   인문계열   인문과학         22       NaN        21               1
# ...    ...  ..    ...    ...        ...       ...       ...             ...
# 3712  2023  대구   자연계열   생활과학        220       NaN       199               0
# 3713  2023  충남   인문계열   인문과학         16       NaN        16               0
# 3714  2023  충남   공학계열     건축         21       NaN        21               0
# 3715  2023  충남   공학계열     건축         16       NaN        16               0
# 3716  2023  충남  예체능계열   응용예술         41       NaN        41               0
#
# ...

# %%
im_2022 = list(future_2022['immigration'].values)
print(im_2022)
# Out:
# [223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 527, 560, 560, 560, 560, 560, 560, 560, 560, 560, 560, 560, 560, 560, 560, 560, 560, 560, 56
# ...

# %%
nm_2022 = list(future_2022['Net_Mover'].values)
print(nm_2022)
# Out:
# [9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, 9191.0, -24642.0, -24642.0, -24642.0, -24642.0, -24642.0, -24642.0, -24642.0, -24642.0, -24642.0, -24642.0, -24642.0, -24642.0, -24642.0, -24642.0, -24642.0, -24642.0, -24642.0, -24642.0, -24642.0, -24642.0, -24642.0, -24642.0, -24642.0, -24642.
# ...

# %%
ft_2022 = list(future_2022['Total_fertility_rate'].values)
print(ft_2022)
# Out:
# [0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.7115, 0.7115, 0.7115, 0.7115, 0.7115, 0.7115, 0.7115, 0.7115, 0.7115, 0.7115, 0.7115, 0.7115, 0.7115, 0.7115, 0.7115, 0.7115, 0.7115, 0.7115, 0.7115, 0.7115, 0.7115, 0.7115, 0.7115, 0.7115, 0.7115, 0.7115, 0.7115, 0.7115, 0.7115, 0.711
# ...

# %%
avg_net = []
for i in range(len(sub_2019)) :
    net_mover_2019 = sub_2019.loc[i]
    net_mover_2020 = sub_2020.loc[i]
    net_mover_2021 = sub_2021.loc[i]
    net_mover_dif = (float(net_mover_2019['Net_Mover']) - float(net_mover_2020['Net_Mover'])) + (float(net_mover_2020['Net_Mover']) - float(net_mover_2021['Net_Mover']))
    avg_net.append(net_mover_dif / 2)
print(avg_net)
# Out:
# [28327.5, -2225.5, 323.0, -6880.0, 1004.0, -3705.5, 1751.0, 4819.5, -7925.5, -2510.0, -448.5, -4658.0, -3473.5, -2150.5, -3954.0, 2196.5, -490.5]

# %%
avg_imm = []
for i in range(len(sub_2019)) :
    immigration_2019 = sub_2019.loc[i]
    immigration_2020 = sub_2020.loc[i]
    immigration_2021 = sub_2021.loc[i]
    # print(immigration_2019)
    # print(immigration_2020)
    immigration_dif = (float(immigration_2019['immigration']) - float(immigration_2020['immigration'])) + (float(immigration_2020['immigration']) - float(immigration_2021['immigration']))
    avg_imm.append(immigration_dif / 2)
print(avg_imm)
# Out:
# [4585.0, 867.0, 571.0, 950.0, 409.0, 359.0, 189.0, 89.0, 5417.0, 193.0, 83.0, 412.0, 199.0, 415.0, 121.0, 358.0, 130.0]

# %%
avg_ft = []
for i in range(len(sub_2019)) :
    fertility_rate_2019 = sub_2019.loc[i]
    fertility_rate_2020 = sub_2020.loc[i]
    fertility_rate_2021 = sub_2021.loc[i]
    fertility_rate_dif = (float(fertility_rate_2019['Total_fertility_rate']) - float(fertility_rate_2020['Total_fertility_rate'])) + (float(fertility_rate_2020['Total_fertility_rate']) - float(fertility_rate_2021['Total_fertility_rate']))
    avg_ft.append(fertility_rate_dif / 2)
print(avg_ft)
# Out:
# [0.045499999999999985, 0.04949999999999999, 0.07350000000000001, 0.08099999999999996, 0.008500000000000008, 0.03649999999999998, 0.07200000000000006, 0.09750000000000003, 0.044999999999999984, 0.051500000000000046, 0.050500000000000045, 0.07450000000000007, 0.0605, 0.10850000000000004, 0.0615, 0.07150000000000001, 0.09700000000000003]

# %%
for i in range(len(future_2023)) :
    # for j in range(len(sub_2022)) :
        target_2023 = future_2023.loc[i]
        # target = sub_2022.loc[j]
        if(target_2023['시도']=='서울') :
            future_2023.iat[i,12] = float(im_2022[0]) - float(avg_imm[0])
            future_2023.iat[i,11] = float(nm_2022[0]) - float(avg_net[0])
            future_2023.iat[i,10] = float(ft_2022[0]) - float(avg_ft[0])
        elif(target_2023['시도']=='부산') :
            future_2023.iat[i,12] = float(im_2022[1]) - float(avg_imm[1])
            future_2023.iat[i,11] = float(nm_2022[1]) - float(avg_net[1])
            future_2023.iat[i,10] = float(ft_2022[1]) - float(avg_ft[1])
        elif(target_2023['시도']=='대구') :
            future_2023.iat[i,12] = float(im_2022[2]) - float(avg_imm[2])
            future_2023.iat[i,11] = float(nm_2022[2]) - float(avg_net[2])
            future_2023.iat[i,10] = float(ft_2022[2]) - float(avg_ft[2])
        elif(target_2023['시도']=='인천') :
            future_2023.iat[i,12] = float(im_2022[3]) - float(avg_imm[3])
            future_2023.iat[i,11] = float(nm_2022[3]) - float(avg_net[3])
            future_2023.iat[i,10] = float(ft_2022[3]) - float(avg_ft[3])
        elif(target_2023['시도']=='광주') :
            future_2023.iat[i,12] = float(im_2022[4]) - float(avg_imm[4])
            future_2023.iat[i,11] = float(nm_2022[4]) - float(avg_net[4])
            future_2023.iat[i,10] = float(ft_2022[4]) - float(avg_ft[4])
        elif(target_2023['시도']=='대전') :
            future_2023.iat[i,12] = float(im_2022[5]) - float(avg_imm[5])
            future_2023.iat[i,11] = float(nm_2022[5]) - float(avg_net[5])
            future_2023.iat[i,10] = float(ft_2022[5]) - float(avg_ft[5])
        elif(target_2023['시도']=='울산') :
            future_2023.iat[i,12] = float(im_2022[6]) - float(avg_imm[6])
            future_2023.iat[i,11] = float(nm_2022[6]) - float(avg_net[6])
            future_2023.iat[i,10] = float(ft_2022[6]) - float(avg_ft[6])
        elif(target_2023['시도']=='세종') :
            future_2023.iat[i,12] = float(im_2022[7]) - float(avg_imm[7])
            future_2023.iat[i,11] = float(nm_2022[7]) - float(avg_net[7])
            future_2023.iat[i,10] = float(ft_2022[7]) - float(avg_ft[7])
        elif(target_2023['시도']=='경기') :
            future_2023.iat[i,12] = float(im_2022[8]) - float(avg_imm[8])
            future_2023.iat[i,11] = float(nm_2022[8]) - float(avg_net[8])
            future_2023.iat[i,10] = float(ft_2022[8]) - float(avg_ft[8])
        elif(target_2023['시도']=='강원') :
            future_2023.iat[i,12] = float(im_2022[9]) - float(avg_imm[9])
            future_2023.iat[i,11] = float(nm_2022[9]) - float(avg_net[9])
            future_2023.iat[i,10] = float(ft_2022[9]) - float(avg_ft[9])
        elif(target_2023['시도']=='충북') :
            future_2023.iat[i,12] = float(im_2022[10]) - float(avg_imm[10])
            future_2023.iat[i,11] = float(nm_2022[10]) - float(avg_net[10])
            future_2023.iat[i,10] = float(ft_2022[10]) - float(avg_ft[10])
        elif(target_2023['시도']=='충남') :
            future_2023.iat[i,12] = float(im_2022[11]) - float(avg_imm[11])
            future_2023.iat[i,11] = float(nm_2022[11]) - float(avg_net[11])
            future_2023.iat[i,10] = float(ft_2022[11]) - float(avg_ft[11])
        elif(target_2023['시도']=='전북') :
            future_2023.iat[i,12] = float(im_2022[12]) - float(avg_imm[12])
            future_2023.iat[i,11] = float(nm_2022[12]) - float(avg_net[12])
            future_2023.iat[i,10] = float(ft_2022[12]) - float(avg_ft[12])
        elif(target_2023['시도']=='전남') :
            future_2023.iat[i,12] = float(im_2022[13]) - float(avg_imm[13])
            future_2023.iat[i,11] = float(nm_2022[13]) - float(avg_net[13])
            future_2023.iat[i,10] = float(ft_2022[13]) - float(avg_ft[13])
        elif(target_2023['시도']=='경북') :
            future_2023.iat[i,12] = float(im_2022[14]) - float(avg_imm[14])
            future_2023.iat[i,11] = float(nm_2022[14]) - float(avg_net[14])
            future_2023.iat[i,10] = float(ft_2022[14]) - float(avg_ft[14])
        elif(target_2023['시도']=='경남') :
            future_2023.iat[i,12] = float(im_2022[15]) - float(avg_imm[15])
            future_2023.iat[i,11] = float(nm_2022[15]) - float(avg_net[15])
            future_2023.iat[i,10] = float(ft_2022[15]) - float(avg_ft[15])
        elif(target_2023['시도']=='제주') :
            future_2023.iat[i,12] = float(im_2022[16]) - float(avg_imm[16])
            future_2023.iat[i,11] = float(nm_2022[16]) - float(avg_net[16])
            future_2023.iat[i,10] = float(ft_2022[16]) - float(avg_ft[16])
# future_2022['Total_fertility_rate']

# %%
future_2023
# Out:
#         연도  시도    대계열    중계열  모집인원_학부_계  지원자_전체_계  입학자_전체_계  Gov_Spnsorship  \
# 0     2023  강원   인문계열  언어ㆍ문학         33       NaN        35               1
# 1     2023  강원   인문계열  언어ㆍ문학         26       NaN        26               1
# 2     2023  강원   인문계열  언어ㆍ문학         33       NaN        34               1
# 3     2023  강원   인문계열  언어ㆍ문학         19       NaN        18               1
# 4     2023  강원   인문계열   인문과학         22       NaN        21               1
# ...    ...  ..    ...    ...        ...       ...       ...             ...
# 3712  2023  대구   자연계열   생활과학        220       NaN       199               0
# 3713  2023  충남   인문계열   인문과학         16       NaN        16               0
# 3714  2023  충남   공학계열     건축         21       NaN        21               0
# 3715  2023  충남   공학계열     건축         16       NaN        16               0
# 3716  2023  충남  예체능계열   응용예술         41       NaN        41               0
#
# ...

# %%
future_2023.to_excel('2023.xlsx',index=False)
