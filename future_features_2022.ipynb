# %% [markdown]
# <a href="https://colab.research.google.com/github/jeewonkimm2/Business_Analytics/blob/main/future_features_2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import csv
# from pandas import DataFrame

# %%
main = pd.read_excel('merged_data.xlsx', engine='openpyxl')

# %%
main
# Out:
#          연도  시도    대계열    중계열  모집인원_학부_계  지원자_전체_계  입학자_전체_계  Gov_Spnsorship  \
# 0      2015  강원   인문계열  언어ㆍ문학         38       238        37               1
# 1      2015  강원   인문계열  언어ㆍ문학         27       154        26               1
# 2      2015  강원   인문계열  언어ㆍ문학         38       193        36               1
# 3      2015  강원   인문계열  언어ㆍ문학         23       118        23               1
# 4      2015  강원   인문계열   인문과학         27       174        27               1
# ...     ...  ..    ...    ...        ...       ...       ...             ...
# 46521  2021  충남   인문계열   인문과학         16       105        16               0
# 46522  2021  충남   인문계열   인문과학          5         0         0               0
# 46523  2021  충남   공학계열     건축         21       105        21               0
# 46524  2021  충남   공학계열     건축         16        76        16               0
# 46525  2021  충남  예체능계열   응용예술         41        90        41               0
#
# ...

# %%
main_2015 = main[main['연도']==2015]
# main_2015
main_2016 = main[main['연도']==2016]
# main_2016
main_2017 = main[main['연도']==2017]
# main_2017
main_2018 = main[main['연도']==2018]
# main_2018
main_2019 = main[main['연도']==2019]
# main_2019
main_2020 = main[main['연도']==2020]
# main_2020
main_2021 = main[main['연도']==2021]
# main_2021

# %%
a_2015 = []
a_2015 = main_2015['학교_학과명'].values
a_2015 = set(a_2015)
print(a_2015)
# print(len(a_2015))

a_2016 = []
a_2016 = main_2016['학교_학과명'].values
a_2016 = set(a_2016)
print(a_2016)
# print(a_2016.size)

a_2017 = []
a_2017 = main_2017['학교_학과명'].values
a_2017 = set(a_2017)
print(a_2017)
# print(a_2017.size)

a_2018 = []
a_2018 = main_2018['학교_학과명'].values
a_2018 = set(a_2018)
print(a_2018)
# print(a_2018.size)

a_2019 = []
a_2019 = main_2019['학교_학과명'].values
a_2019 = set(a_2019)
print(a_2019)
# print(a_2019.size)

a_2020 = []
a_2020 = main_2020['학교_학과명'].values
a_2020 = set(a_2020)
print(a_2020)
# print(a_2020.size)

a_2021 = []
a_2021 = main_2021['학교_학과명'].values
a_2021 = set(a_2021)
print(a_2021)
# # print(a_2021.size)

b = a_2015.intersection(a_2016)
# print(len(b))
b = b.intersection(a_2017)
# print(len(b))
b = b.intersection(a_2018)
# print(len(b))
b = b.intersection(a_2019)
# print(len(b))
b = b.intersection(a_2020)
# print(len(b))
b = b.intersection(a_2021)
# print(len(b))
bl = list(b)

print(bl)
print(len(bl))
# print(len(b))
# print(b.size)
main_check = main.loc[main['학교_학과명'].isin(bl)]
print(main_check['학교_학과명'].values)
print((main_check['학교_학과명'].values).size)
# Out:
# {'부경대학교_법학과', '수원대학교_전자공학과', '경희대학교_중국어학과', '전북대학교_컴퓨터공학부', '한남대학교_중국경제통상학과', '광주여자대학교_중등특수교육과', '동아대학교_기계공학과', '충남대학교_조소과', '상지대학교_경제학과', '영산대학교_아세안비즈니스학과', '서원대학교_국어교육과', '청주대학교_임상병리학과', '국민대학교_일본학전공', '나사렛대학교_재활자립학과', '가톨릭관동대학교_가정교육과', '부경대학교_응용수학과', '중부대학교_경찰행정학과', '청주대학교_국어국문학과', '서울대학교_국악과', '우석대학교_경영학과', '한국체육대학교_특수체육교육과', '경일대학교_사이버보안학과', '우석대학교_국제언어문화학과', '남서울대학교_컴퓨터학과', '연세대학교 원주캠퍼스_의예과', '대진대학교_신소재공학과', '호서대학교_식품영양학전공', '공주대학교_법학과', '대구외국어대학교_외국어학부', '영산대학교_물리치료학과', '추계예술대학교_피아노과', '대구대학교_의생명과학과', '인천대학교_무역학부', '가천대학교_미술·디자인학부(패션디자인)', '상지대학교_관광학부 관광개발학전공', '인제대학교_통계학과', '충남대학교_한문학과', '군산대학교_행정경제학부', '강원대학교_간호학과', '칼빈대학교_실용음악과', '서울대학교_경영대학', '삼육대학교_동물생명자원학과', '안동대학교_회계학과', '가톨릭대학교_프랑스어문화학과', '한국교통대학교_에너지시스템공학과', '총신대학교_기독교교육과', '한국외국어대학교_정보통신공학과', '강원대학교_산림환경보호학전공', '가톨릭관동대학교_지리교육과', '예원예술대학교_호텔관광경영학과', '경기대학교_도예학과', '연세대학교_지구시스템과학과', '동국대학교_수학교육과', '충남대학교_농업경제학과', '호남대학교_작업치료학과', '영남대학교_국어교육과', '한국외국어대학교_프랑스학과', '순천대학교_컴퓨터공학과', '경북대학교_섬유패션디자인학부 패션디자인전공', '한국국제대학교_토지주택개발학
# ...

# %%
main_2015 = main_check[main_check['연도']==2015]
# main_2015
main_2016 = main_check[main_check['연도']==2016]
# main_2016
main_2017 = main_check[main_check['연도']==2017]
# main_2017
main_2018 = main_check[main_check['연도']==2018]
# main_2018
main_2019 = main_check[main_check['연도']==2019]
# main_2019
main_2020 = main_check[main_check['연도']==2020]
# main_2020
main_2021 = main_check[main_check['연도']==2021]
# main_2021

# %%
print(main_2015)
print(main_2016)
print(main_2017)
print(main_2018)
print(main_2019)
print(main_2020)
print(main_2021)
# Out:
#         연도  시도    대계열    중계열  모집인원_학부_계  지원자_전체_계  입학자_전체_계  Gov_Spnsorship  \
# 0     2015  강원   인문계열  언어ㆍ문학         38       238        37               1
# 1     2015  강원   인문계열  언어ㆍ문학         27       154        26               1
# 2     2015  강원   인문계열  언어ㆍ문학         38       193        36               1
# 3     2015  강원   인문계열  언어ㆍ문학         23       118        23               1
# 4     2015  강원   인문계열   인문과학         27       174        27               1
# ...    ...  ..    ...    ...        ...       ...       ...             ...
# 6758  2015  대구   자연계열   생활과학        200      1677       203               0
# 6759  2015  충남   인문계열   인문과학         21       243        18               0
# 6762  2015  충남   공학계열     건축         21       126        21               0
# 6763  2015  충남   공학계열     건축         21       100        20               0
# 6764  2015  충남  예체능계열   응용예술         42       142        40               0
#
# ...

# %%
main_2015.duplicated(['학교_학과명'], keep=False)


# duplicate_2015 = main_2015[main_2015.duplicated(['학교_학과명'])==True]

# print(duplicate_2015)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6758    False
# 6759    False
# 6762    False
# 6763    False
# 6764    False
# Length: 3733, dtype: bool

# %%
# keep = 'first'   중복값 중 처음값만 표시

main_2015 = main_2015.drop_duplicates(['학교_학과명'], keep='first')
print(len(main_2015))
main_2016 = main_2016.drop_duplicates(['학교_학과명'], keep='first')
print(len(main_2016))
main_2017 = main_2017.drop_duplicates(['학교_학과명'], keep='first')
print(len(main_2017))
main_2018 = main_2018.drop_duplicates(['학교_학과명'], keep='first')
print(len(main_2018))
main_2019 = main_2019.drop_duplicates(['학교_학과명'], keep='first')
print(len(main_2019))
main_2020 = main_2020.drop_duplicates(['학교_학과명'], keep='first')
print(len(main_2020))
main_2021 = main_2021.drop_duplicates(['학교_학과명'], keep='first')
print(len(main_2021))
# Out:
# 3717
# 3717
# 3717
# 3717
# 3717
# 3717
# 3717

# %%
result = pd.concat([main_2015, main_2016, main_2017, main_2018, main_2019, main_2020, main_2021])
result
# Out:
#          연도  시도    대계열    중계열  모집인원_학부_계  지원자_전체_계  입학자_전체_계  Gov_Spnsorship  \
# 0      2015  강원   인문계열  언어ㆍ문학         38       238        37               1
# 1      2015  강원   인문계열  언어ㆍ문학         27       154        26               1
# 2      2015  강원   인문계열  언어ㆍ문학         38       193        36               1
# 3      2015  강원   인문계열  언어ㆍ문학         23       118        23               1
# 4      2015  강원   인문계열   인문과학         27       174        27               1
# ...     ...  ..    ...    ...        ...       ...       ...             ...
# 46517  2021  대구   자연계열   생활과학        220      3199       199               0
# 46519  2021  충남   인문계열   인문과학         16       157        16               0
# 46523  2021  충남   공학계열     건축         21       105        21               0
# 46524  2021  충남   공학계열     건축         16        76        16               0
# 46525  2021  충남  예체능계열   응용예술         41        90        41               0
#
# ...

# %%
result.to_excel('main.xlsx', index = False)

# %%
future_2022 = pd.read_excel('future_2022.xlsx', engine='openpyxl')
sub_2021 = pd.read_excel('2021_sub_1.xlsx', engine='openpyxl')
sub_2020 = pd.read_excel('2020_sub_1.xlsx', engine='openpyxl')
sub_2019 = pd.read_excel('2019_sub_1.xlsx', engine='openpyxl')

# %%
future_2022
# Out:
#         연도  시도    대계열    중계열  모집인원_학부_계  지원자_전체_계  입학자_전체_계  Gov_Spnsorship  \
# 0     2022  강원   인문계열  언어ㆍ문학         33       NaN        35               1
# 1     2022  강원   인문계열  언어ㆍ문학         26       NaN        26               1
# 2     2022  강원   인문계열  언어ㆍ문학         33       NaN        34               1
# 3     2022  강원   인문계열  언어ㆍ문학         19       NaN        18               1
# 4     2022  강원   인문계열   인문과학         22       NaN        21               1
# ...    ...  ..    ...    ...        ...       ...       ...             ...
# 3712  2022  대구   자연계열   생활과학        220       NaN       199               0
# 3713  2022  충남   인문계열   인문과학         16       NaN        16               0
# 3714  2022  충남   공학계열     건축         21       NaN        21               0
# 3715  2022  충남   공학계열     건축         16       NaN        16               0
# 3716  2022  충남  예체능계열   응용예술         41       NaN        41               0
#
# ...

# %%
# sub_2021
# sub_2020
sub_2019
# Out:
#     시도  Total_fertility_rate  Net_Mover  immigration
# 0   서울                 0.717     -49588        27270
# 1   부산                 0.827     -23354         3098
# 2   대구                 0.932     -23673         2240
# 3   인천                 0.940      -2337         3674
# 4   광주                 0.913      -3875         1256
# 5   대전                 0.883     -16342         1952
# 6   울산                 1.084     -10172         1092
# 7   세종                 1.472      23724         1732
# 8   경기                 0.943     134666        27110
# 9   강원                 1.082       1661          802
# 10  충북                 1.050       2565          928
# 11  충남                 1.112       -794         1796
# 12  전북                 0.971     -12748          922
# 13  전남                 1.234      -8788         1202
# 14  경북                 1.089      -4571         1358
# 15  경남                 1.046      -9310         1712
# 16  제주                 1.145       2936          578

# %%
sum = 0
for i in range(len(main_2021)) :
    target = main.loc[i]
    # print(int(target['모집인원_학부_계']))
    entered_dif = int(target['모집인원_학부_계']) - int(target['입학자_전체_계'])
    sum += entered_dif

avg = sum/len(main_2021)
print(avg)
# Out:
# 1.3497444175410278

# %%
schoolage_2022 = 957	 
schoolage_2023 = 922	 
schoolage_2024 = 883	 
schoolage_2025 = 895	 
schoolage_2026 = 943

# %% [markdown]
# **change future features about 2022**

# %%
future_2022['schoolage'] = schoolage_2022

# %%
future_2022
# Out:
#         연도  시도    대계열    중계열  모집인원_학부_계  지원자_전체_계  입학자_전체_계  Gov_Spnsorship  \
# 0     2022  강원   인문계열  언어ㆍ문학         33       NaN        35               1
# 1     2022  강원   인문계열  언어ㆍ문학         26       NaN        26               1
# 2     2022  강원   인문계열  언어ㆍ문학         33       NaN        34               1
# 3     2022  강원   인문계열  언어ㆍ문학         19       NaN        18               1
# 4     2022  강원   인문계열   인문과학         22       NaN        21               1
# ...    ...  ..    ...    ...        ...       ...       ...             ...
# 3712  2022  대구   자연계열   생활과학        220       NaN       199               0
# 3713  2022  충남   인문계열   인문과학         16       NaN        16               0
# 3714  2022  충남   공학계열     건축         21       NaN        21               0
# 3715  2022  충남   공학계열     건축         16       NaN        16               0
# 3716  2022  충남  예체능계열   응용예술         41       NaN        41               0
#
# ...

# %%
im_2021 = list(sub_2021['immigration'].values)
print(im_2021)
# Out:
# [18100, 1364, 1098, 1774, 438, 1234, 714, 1554, 16276, 416, 762, 972, 524, 372, 1116, 996, 318]

# %%
nm_2021 = list(sub_2021['Net_Mover'].values)
print(nm_2021)
# Out:
# [-106243, -18903, -24319, 11423, -5883, -8931, -13674, 14085, 150517, 6681, 3462, 8522, -5801, -4487, 3337, -13703, 3917]

# %%
ft_2021 = list(sub_2021['Total_fertility_rate'].values)
print(ft_2021)
# Out:
# [0.626, 0.728, 0.785, 0.778, 0.896, 0.81, 0.94, 1.277, 0.853, 0.979, 0.949, 0.963, 0.85, 1.017, 0.966, 0.903, 0.951]

# %%
avg_net = []
for i in range(len(sub_2019)) :
    net_mover_2019 = sub_2019.loc[i]
    net_mover_2020 = sub_2020.loc[i]
    net_mover_2021 = sub_2021.loc[i]
    net_mover_dif = (float(net_mover_2019['Net_Mover']) - float(net_mover_2020['Net_Mover'])) + (float(net_mover_2020['Net_Mover']) - float(net_mover_2021['Net_Mover']))
    avg_net.append(net_mover_dif / 2)
print(avg_net)
# Out:
# [28327.5, -2225.5, 323.0, -6880.0, 1004.0, -3705.5, 1751.0, 4819.5, -7925.5, -2510.0, -448.5, -4658.0, -3473.5, -2150.5, -3954.0, 2196.5, -490.5]

# %%
avg_imm = []
for i in range(len(sub_2019)) :
    immigration_2019 = sub_2019.loc[i]
    immigration_2020 = sub_2020.loc[i]
    immigration_2021 = sub_2021.loc[i]
    # print(immigration_2019)
    # print(immigration_2020)
    immigration_dif = (float(immigration_2019['immigration']) - float(immigration_2020['immigration'])) + (float(immigration_2020['immigration']) - float(immigration_2021['immigration']))
    avg_imm.append(immigration_dif / 2)
print(avg_imm)
# Out:
# [4585.0, 867.0, 571.0, 950.0, 409.0, 359.0, 189.0, 89.0, 5417.0, 193.0, 83.0, 412.0, 199.0, 415.0, 121.0, 358.0, 130.0]

# %%
avg_ft = []
for i in range(len(sub_2019)) :
    fertility_rate_2019 = sub_2019.loc[i]
    fertility_rate_2020 = sub_2020.loc[i]
    fertility_rate_2021 = sub_2021.loc[i]
    fertility_rate_dif = (float(fertility_rate_2019['Total_fertility_rate']) - float(fertility_rate_2020['Total_fertility_rate'])) + (float(fertility_rate_2020['Total_fertility_rate']) - float(fertility_rate_2021['Total_fertility_rate']))
    avg_ft.append(fertility_rate_dif / 2)
print(avg_ft)
# Out:
# [0.045499999999999985, 0.04949999999999999, 0.07350000000000001, 0.08099999999999996, 0.008500000000000008, 0.03649999999999998, 0.07200000000000006, 0.09750000000000003, 0.044999999999999984, 0.051500000000000046, 0.050500000000000045, 0.07450000000000007, 0.0605, 0.10850000000000004, 0.0615, 0.07150000000000001, 0.09700000000000003]

# %%
for i in range(len(future_2022)) :
    # for j in range(len(sub_2021)) :
        target_2022 = future_2022.loc[i]
        # target = sub_2021.loc[j]
        if(target_2022['시도']=='서울') :
            future_2022.iat[i,12] = float(im_2021[0]) - float(avg_imm[0])
            future_2022.iat[i,11] = float(nm_2021[0]) - float(avg_net[0])
            future_2022.iat[i,10] = float(ft_2021[0]) - float(avg_ft[0])
            # print(future_2022.iat[i,10])
            # print(float(ft_2021[0]) - float(avg_ft[0]))
        elif(target_2022['시도']=='부산') :
            future_2022.iat[i,12] = float(im_2021[1]) - float(avg_imm[1])
            future_2022.iat[i,11] = float(nm_2021[1]) - float(avg_net[1])
            future_2022.iat[i,10] = float(ft_2021[1]) - float(avg_ft[1])
        elif(target_2022['시도']=='대구') :
            future_2022.iat[i,12] = float(im_2021[2]) - float(avg_imm[2])
            future_2022.iat[i,11] = float(nm_2021[2]) - float(avg_net[2])
            future_2022.iat[i,10] = float(ft_2021[2]) - float(avg_ft[2])
        elif(target_2022['시도']=='인천') :
            future_2022.iat[i,12] = float(im_2021[3]) - float(avg_imm[3])
            future_2022.iat[i,11] = float(nm_2021[3]) - float(avg_net[3])
            future_2022.iat[i,10] = float(ft_2021[3]) - float(avg_ft[3])
        elif(target_2022['시도']=='광주') :
            future_2022.iat[i,12] = float(im_2021[4]) - float(avg_imm[4])
            future_2022.iat[i,11] = float(nm_2021[4]) - float(avg_net[4])
            future_2022.iat[i,10] = float(ft_2021[4]) - float(avg_ft[4])
        elif(target_2022['시도']=='대전') :
            future_2022.iat[i,12] = float(im_2021[5]) - float(avg_imm[5])
            future_2022.iat[i,11] = float(nm_2021[5]) - float(avg_net[5])
            future_2022.iat[i,10] = float(ft_2021[5]) - float(avg_ft[5])
        elif(target_2022['시도']=='울산') :
            future_2022.iat[i,12] = float(im_2021[6]) - float(avg_imm[6])
            future_2022.iat[i,11] = float(nm_2021[6]) - float(avg_net[6])
            future_2022.iat[i,10] = float(ft_2021[6]) - float(avg_ft[6])
        elif(target_2022['시도']=='세종') :
            future_2022.iat[i,12] = float(im_2021[7]) - float(avg_imm[7])
            future_2022.iat[i,11] = float(nm_2021[7]) - float(avg_net[7])
            future_2022.iat[i,10] = float(ft_2021[7]) - float(avg_ft[7])
        elif(target_2022['시도']=='경기') :
            future_2022.iat[i,12] = float(im_2021[8]) - float(avg_imm[8])
            future_2022.iat[i,11] = float(nm_2021[8]) - float(avg_net[8])
            future_2022.iat[i,10] = float(ft_2021[8]) - float(avg_ft[8])
        elif(target_2022['시도']=='강원') :
            future_2022.iat[i,12] = float(im_2021[9]) - float(avg_imm[9])
            future_2022.iat[i,11] = float(nm_2021[9]) - float(avg_net[9])
            future_2022.iat[i,10] = float(ft_2021[9]) - float(avg_ft[9])
        elif(target_2022['시도']=='충북') :
            future_2022.iat[i,12] = float(im_2021[10]) - float(avg_imm[10])
            future_2022.iat[i,11] = float(nm_2021[10]) - float(avg_net[10])
            future_2022.iat[i,10] = float(ft_2021[10]) - float(avg_ft[10])
        elif(target_2022['시도']=='충남') :
            future_2022.iat[i,12] = float(im_2021[11]) - float(avg_imm[11])
            future_2022.iat[i,11] = float(nm_2021[11]) - float(avg_net[11])
            future_2022.iat[i,10] = float(ft_2021[11]) - float(avg_ft[11])
        elif(target_2022['시도']=='전북') :
            future_2022.iat[i,12] = float(im_2021[12]) - float(avg_imm[12])
            future_2022.iat[i,11] = float(nm_2021[12]) - float(avg_net[12])
            future_2022.iat[i,10] = float(ft_2021[12]) - float(avg_ft[12])
        elif(target_2022['시도']=='전남') :
            future_2022.iat[i,12] = float(im_2021[13]) - float(avg_imm[13])
            future_2022.iat[i,11] = float(nm_2021[13]) - float(avg_net[13])
            future_2022.iat[i,10] = float(ft_2021[13]) - float(avg_ft[13])
        elif(target_2022['시도']=='경북') :
            future_2022.iat[i,12] = float(im_2021[14]) - float(avg_imm[14])
            future_2022.iat[i,11] = float(nm_2021[14]) - float(avg_net[14])
            future_2022.iat[i,10] = float(ft_2021[14]) - float(avg_ft[14])
        elif(target_2022['시도']=='경남') :
            future_2022.iat[i,12] = float(im_2021[15]) - float(avg_imm[15])
            future_2022.iat[i,11] = float(nm_2021[15]) - float(avg_net[15])
            future_2022.iat[i,10] = float(ft_2021[15]) - float(avg_ft[15])
        elif(target_2022['시도']=='제주') :
            future_2022.iat[i,12] = float(im_2021[16]) - float(avg_imm[16])
            future_2022.iat[i,11] = float(nm_2021[16]) - float(avg_net[16])
            future_2022.iat[i,10] = float(ft_2021[16]) - float(avg_ft[16])
future_2022['Total_fertility_rate']
# Out:
# 0       0.9275
# 1       0.9275
# 2       0.9275
# 3       0.9275
# 4       0.9275
#          ...
# 3712    0.7115
# 3713    0.8885
# 3714    0.8885
# 3715    0.8885
# 3716    0.8885
# Name: Total_fertility_rate, Length: 3717, dtype: float64

# %%
future_2022
# Out:
#         연도  시도    대계열    중계열  모집인원_학부_계  지원자_전체_계  입학자_전체_계  Gov_Spnsorship  \
# 0     2022  강원   인문계열  언어ㆍ문학         33       NaN        35               1
# 1     2022  강원   인문계열  언어ㆍ문학         26       NaN        26               1
# 2     2022  강원   인문계열  언어ㆍ문학         33       NaN        34               1
# 3     2022  강원   인문계열  언어ㆍ문학         19       NaN        18               1
# 4     2022  강원   인문계열   인문과학         22       NaN        21               1
# ...    ...  ..    ...    ...        ...       ...       ...             ...
# 3712  2022  대구   자연계열   생활과학        220       NaN       199               0
# 3713  2022  충남   인문계열   인문과학         16       NaN        16               0
# 3714  2022  충남   공학계열     건축         21       NaN        21               0
# 3715  2022  충남   공학계열     건축         16       NaN        16               0
# 3716  2022  충남  예체능계열   응용예술         41       NaN        41               0
#
# ...

# %%
future_2022.to_excel('2022.xlsx',index=False)
